# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('pakaian_pria_shopee_sales_cleaning.csv')

# %% [markdown]
# ### What is the most sales in sub-category market?
# ### What is the suitable sub-category market for newcomers in Shopee Indonesia?

# %%
sns.displot(df, x='harga_rata2', hue='kategori', multiple="stack", kde=True)
plt.xlim(0, 200000)
plt.xticks(rotation=90)
plt.title('Category Distribution')
sns.set()

# %%
sns.displot(df, x='harga_rata2', hue='jenis', multiple="stack", kde=True)
plt.xlim(0, 200000)
plt.xticks(rotation=90)
plt.title('Sub-category Distribution')
sns.set()

# %%
sns.displot(df, x='terjual', hue='kategori', multiple="stack")
plt.xticks(rotation=90)
plt.title('Sales based on Category')
sns.set()

# %%
sns.displot(df, x='terjual', hue='jenis', multiple="stack")
plt.xticks(rotation=90)
plt.title('Sales based on Sub-category')
sns.set()

# %% [markdown]
# #### Based on the data distribution and sales plot, atasan(top) with kaos(t-shirt), pakaian dalam(underclothes) with boxer, and celana panjang(trouser) with chino are the top 3 sales in Shopee Indonesia market. For further analysis, I identify every sub-category in the existing market

# %%
df[df['jenis'] == 'kaos'].groupby(['toko'])['nama'].count().sort_values(ascending=False).head(10)
# Out:
# toko
# erigostore           64
# gns_collection       28
# kaosdantas.import    15
# asy168               14
# fairgoods            14
# ark_shop99           12
# indomarket999        11
# tompelaje            10
# simonsimonchia        7
# dionjeans             7
# Name: nama, dtype: int64

# %%
df[df['jenis'] == 'kaos'].groupby(['lokasi'])['nama'].count().sort_values(ascending=False).head(10)
# Out:
# lokasi
# jakarta barat         218
# bandung               156
# tangerang              99
# cimahi                 53
# surabaya               27
# jakarta utara          27
# magelang               16
# tangerang selatan      14
# semarang               12
# jakarta pusat          11
# Name: nama, dtype: int64

# %%
df[df['jenis'] == 'boxer'].groupby(['toko'])['nama'].count().sort_values(ascending=False).head(10)
# Out:
# toko
# surfinclo.id         6
# distrobm             5
# ss_fashion           4
# ciaraofficialshop    4
# vayamadelon          3
# komandanbatik        3
# wimigrosir           3
# ayumicollection.     3
# mbakdiva             2
# dollietories         2
# Name: nama, dtype: int64

# %%
df[df['jenis'] == 'boxer'].groupby(['lokasi'])['nama'].count().sort_values(ascending=False).head(10)
# Out:
# lokasi
# jakarta barat        30
# bandung              23
# pekalongan           14
# jakarta utara        14
# tangerang            11
# surakarta (solo)      6
# bogor                 5
# klaten                5
# bekasi                4
# jakarta pusat         4
# Name: nama, dtype: int64

# %%
df[df['jenis'] == 'chino'].groupby(['toko'])['nama'].count().sort_values(ascending=False).head(10)
# Out:
# toko
# erigostore            9
# thufail05             7
# arj88store            7
# pieter.pieter         5
# firzanfashion         4
# cixstore              4
# molrakyat             4
# djakastore            4
# zafik_store           4
# rhimfashion_wanita    4
# Name: nama, dtype: int64

# %%
df[df['jenis'] == 'chino'].groupby(['lokasi'])['nama'].count().sort_values(ascending=False).head(10)
# Out:
# lokasi
# pekalongan        97
# bandung           18
# kudus             17
# tangerang         13
# jepara            13
# denpasar           8
# pemalang           7
# bekasi             7
# jakarta barat      6
# semarang           5
# Name: nama, dtype: int64

# %%
df[df['toko'] == 'erigostore'].head(3)
# Out:
#                                   nama        kategori  jenis      lokasi  \
# 10      Erigo Chino Pants Sirius Black  Celana Panjang  chino  tangerang
# 70  Erigo T-Shirt Project Summer Black          Atasan   kaos  tangerang
# 79   Erigo Chino Pants Paul Light Grey  Celana Panjang  chino  tangerang
#
#     harga_rata2  terjual  rating  jumlah_review        toko  umur_bulan_toko  \
# 10     128000.0    10000     4.8          79500  erigostore               48
# 70      65000.0    10000     4.9          32900  erigostore               48
# 79     128000.0    10000     4.8          20900  erigostore               48
#
#     n_produk_toko  pengikut_toko
# 10           2200        2300000
# 70           2200        2300000
# 79           2200        2300000

# %%
df[df['toko'] == 'surfinclo.id'].head(3)
# Out:
#                                                   nama       kategori  jenis  \
# 95   StarSURFINCLO Boxer Polos Cotton Combed 30s & ...  Pakaian Dalam  boxer
# 430  StarBEST SELLER!!! 12.12 - SURFINCLO CELANA BO...  Celana Pendek    NaN
# 538  StarSPECTA BOXER RADER 211W AUTHENTIC+ | BOXER...  Pakaian Dalam  boxer
#
#        lokasi  harga_rata2  terjual  rating  jumlah_review          toko  \
# 95   bandung       40000.0    10000     4.7           4800  surfinclo.id
# 430  bandung       31250.0    10000     4.7          15500  surfinclo.id
# 538  bandung       41250.0    10000     4.6           8800  surfinclo.id
#
#      umur_bulan_toko  n_produk_toko  pengikut_toko
# 95                28            317         185200
# 430               28            317         185200
# 538               28            317         185300

# %%
df[df['toko'] == 'distrobm'].head(3)
# Out:
#                                                   nama       kategori  jenis  \
# 8    BEST SELLER - BOXER PRIA I BOXER WANITA I CELA...  Pakaian Dalam  boxer
# 308  BOXER DISTRO !! - I CELANA PENDEK I CELANA KOL...  Pakaian Dalam  boxer
# 394  BOXER SALUR - BEST SELLER 12.12 - | CELANA DAL...  Pakaian Dalam  boxer
#
#        lokasi  harga_rata2  terjual  rating  jumlah_review      toko  \
# 8    bandung       18200.0    10000     4.7          21300  distrobm
# 308  bandung       18750.0    10000     4.8           6800  distrobm
# 394  bandung       18750.0    10000     4.8           5400  distrobm
#
#      umur_bulan_toko  n_produk_toko  pengikut_toko
# 8                 48            211          49600
# 308               48            211          49600
# 394               48            211          49600

# %%
df[df['toko'] == 'ss_fashion'].head(3)
# Out:
#                                                  nama       kategori  jenis  \
# 23                    celana dalam pria CD pria lokal  Pakaian Dalam    NaN
# 42   boxer munafie pria import new stripes kode: 8027  Pakaian Dalam  boxer
# 56  COD celana dalam pria import CD munafie fashio...  Pakaian Dalam    NaN
#
#             lokasi  harga_rata2  terjual  rating  jumlah_review        toko  \
# 23  jakarta barat        3145.0    10000     4.5           4200  ss_fashion
# 42  jakarta barat        8800.0    10000     4.8           2500  ss_fashion
# 56  jakarta barat        8740.0    10000     4.8           3400  ss_fashion
#
#     umur_bulan_toko  n_produk_toko  pengikut_toko
# 23               48            450         621100
# 42               48            450         621100
# 56               48            450         621100

# %% [markdown]
# #### The Boxer is the least competition in the market. with the relatively small price, its suitable for newcomers to open online store in the boxer market. while tshirt and chino market are dominated by big store like erigostore with 2.3M follower, which is very popular and also the capital or money you need to get in into the market will be bigger than boxer market for newcomers.

# %% [markdown]
# #### The most popular sub-category in Shopee Indonesia market are kaos(t-shirt), boxer, and chino as top 3 product in the market. these 3 products could be the niche for marketing research for newcomers in another e-commerce market, if the immigration happen from Shopee to another platform.

# %% [markdown]
# ### what is the most effective store?

# %%
df.head(3)
# Out:
#                                                 nama kategori jenis  \
# 0  Star+[PROMO] KAOS POLOS LENGAN PENDEK COTTON C...   Atasan  kaos
# 1    Star+KAOS POLOS LENGAN PENDEK COTTON COMBED 30S   Atasan  kaos
# 2  StarKaos Polos Cotton Combed 30s Distro Grosir...   Atasan  kaos
#
#            lokasi  harga_rata2  terjual  rating  jumlah_review  \
# 0  jakarta utara       27800.0    10000     4.9          90600
# 1        bandung       23900.0    10000     4.8          71800
# 2        bandung       23900.0    10000     4.7          80000
#
#                 toko  umur_bulan_toko  n_produk_toko  pengikut_toko
# 0  tokyo_urban_style               18              5          74600
# 1  yoonacollection24               36             21          58600
# 2          kaospedia               36             39         105700

# %%
df[df.umur_bulan_toko <= 3].sort_values(by=['terjual'], ascending=False).head()
# Out:
#                                                    nama        kategori  \
# 705   Star[Bisa COD] Celana Pendek Pria Cowok Dewasa...   Celana Pendek
# 964   Star(BISA COD) Celana Kerja Pria / Celana Baha...  Celana Panjang
# 96    Star+KAOS POLOS OVERSIZE UNISEX COTTON COMBED ...          Atasan
# 1964  Star[Bisa COD Promo 12:12] Celana  Panjang Pri...  Celana Panjang
# 2229  StarBaju Kemeja Pria / Kemeja Lengan Panjang /...          Atasan
#
#               jenis       lokasi  harga_rata2  terjual  rating  jumlah_review  \
# 705             NaN  pekalongan       25799.5    10000     4.6            347
# 964             NaN  pekalongan       57899.5    10000     4.6            454
# 96             kaos     bandung       64480.0     9400     4.9           3600
# 1964          chino  pekalongan       45000.0     5600     4.6            376
# 2229  kemeja kasual  pekalongan       44300.0     4700     4.7            218
#
#               toko  umur_bulan_toko  n_produk_toko  pengikut_toko
# 705        d3wisri                2             40           1800
# 964   _pacolgowang                2             15           1300
# 96    qrproject.id                3              7          13200
# 1964  sneber_store                2             17           1600
# 2229   a.l_store01                2             18            358

# %%
df[df.umur_bulan_toko <= 3].sort_values(by=['pengikut_toko'], ascending=False).head()
# Out:
#                                                    nama        kategori  \
# 96    Star+KAOS POLOS OVERSIZE UNISEX COTTON COMBED ...          Atasan
# 2270                                        Just Do Eat          Atasan
# 1264  StarKemeja Flanel Import Pria Wanita Distro Fl...          Atasan
# 1948  SETELAN STELAN JAS BLAZER BLEZER NIKAH KOREA N...       Outerwear
# 1949  CELANA JOGER JOGGER TRAINING SANTAI KARET HYPE...  Celana Panjang
#
#               jenis        lokasi  harga_rata2  terjual  rating  \
# 96             kaos      bandung       64480.0     9400     4.9
# 2270           kaos    tangerang      120000.0     1300     4.9
# 1264  kemeja kasual     pemalang       47500.0     2900     4.7
# 1948            NaN  tasikmalaya      365000.0     1200     5.0
# 1949         jogger  tasikmalaya       64400.0     2100     5.0
#
#       jumlah_review                 toko  umur_bulan_toko  n_produk_toko  \
# 96             3600         qrproject.id                3              7
# 2270            675            nexcolony                3              5
# 1264            351      salsabilah_stor                3             15
# 1948             20  fathershop.official                2             47
# 1949             20  fathershop.official                2             47
#
#       pengikut_toko
# 96            13200
# 2270           3000
# 1264           2000
# 1948           2000
# 1949           2000

# %%
df[df.umur_bulan_toko <= 3].sort_values(by=['terjual'], ascending=False).sort_values(by=['pengikut_toko'], ascending=False).head()
# Out:
#                                                    nama        kategori  \
# 96    Star+KAOS POLOS OVERSIZE UNISEX COTTON COMBED ...          Atasan
# 2270                                        Just Do Eat          Atasan
# 1949  CELANA JOGER JOGGER TRAINING SANTAI KARET HYPE...  Celana Panjang
# 1264  StarKemeja Flanel Import Pria Wanita Distro Fl...          Atasan
# 2185  CELANA FORMAL BAHAN KERJA KANTOR PRIA SLIM FIT...  Celana Panjang
#
#               jenis        lokasi  harga_rata2  terjual  rating  \
# 96             kaos      bandung       64480.0     9400     4.9
# 2270           kaos    tangerang      120000.0     1300     4.9
# 1949         jogger  tasikmalaya       64400.0     2100     5.0
# 1264  kemeja kasual     pemalang       47500.0     2900     4.7
# 2185            NaN  tasikmalaya      149000.0      876     5.0
#
#       jumlah_review                 toko  umur_bulan_toko  n_produk_toko  \
# 96             3600         qrproject.id                3              7
# 2270            675            nexcolony                3              5
# 1949             20  fathershop.official                2             47
# 1264            351      salsabilah_stor                3             15
# 2185             19  fathershop.official                2             47
#
#       pengikut_toko
# 96            13200
# 2270           3000
# 1949           2000
# 1264           2000
# 2185           2000

# %%
df[df.umur_bulan_toko <= 6].sort_values(by=['terjual'], ascending=False).sort_values(by=['pengikut_toko'], ascending=False).head(10)
# Out:
#                                                    nama       kategori  \
# 1631  Star+Celana Dalam Pria Munafie BOXER MAN UNDER...  Pakaian Dalam
# 101   Star+Baru CD Munafie Celana Dalam Boxer Munafi...  Pakaian Dalam
# 841   Kemeja Flanel Impor Pria Wanita Casual Distro,...         Atasan
# 96    Star+KAOS POLOS OVERSIZE UNISEX COTTON COMBED ...         Atasan
# 354   StarKemeja Flanel Impor Pria Wanita Distro Fla...         Atasan
# 1178  ✨WINGALERY✨ Celana Dalam Boxer Pria Munafie Cd...  Pakaian Dalam
# 1268  ✨WINGALERY✨  Celana Dalam Pria/MUNAFIE UNDERWE...  Pakaian Dalam
# 1167  ✨WINGALERY✨CELANA DALAM MUNAFIE PRIA CELANA DA...  Pakaian Dalam
# 365   Star[COD] Eighty Nine Crewneck Black Motif Sim...      Outerwear
# 1554  StarCelana jeans pria panjang slim fit skiny l...          Jeans
#
#                    jenis          lokasi  harga_rata2  terjual  rating  \
# 1631               boxer  jakarta utara       11900.0      698     4.8
# 101                boxer  jakarta utara        9025.0     6700     4.9
# 841        kemeja kasual       pemalang       48000.0     8200     4.8
# 96                  kaos        bandung       64480.0     9400     4.9
# 354        kemeja kasual       pemalang       47600.0     9600     4.7
# 1178                 NaN  jakarta utara        9038.0     3200     4.8
# 1268                 NaN  jakarta utara        8820.0     1100     4.9
# 1167                 NaN  jakarta utara        8989.0     3300     4.9
# 365   sweater & kardigan        bandung       85000.0     5500     4.7
# 1554      slim fit jeans     pekalongan       41000.0     3100     4.8
#
#       jumlah_review              toko  umur_bulan_toko  n_produk_toko  \
# 1631            169        sexy.crowd                5             71
# 101            1100        sexy.crowd                5             71
# 841            1500     erwinstore123                6             41
# 96             3600      qrproject.id                3              7
# 354            1600       anfashion11                5             29
# 1178            329         wingalery                6            140
# 1268            158         wingalery                6            140
# 1167            348         wingalery                6            140
# 365            2800  zerofourofficial                5             78
# 1554            954         mrr_denim                5             14
#
#       pengikut_toko
# 1631          21800
# 101           21700
# 841           14800
# 96            13200
# 354           11200
# 1178           8600
# 1268           8600
# 1167           8600
# 365            7600
# 1554           6100

# %%
df[df['toko'] == 'qrproject.id']
# Out:
#                                                  nama kategori jenis  \
# 96  Star+KAOS POLOS OVERSIZE UNISEX COTTON COMBED ...   Atasan  kaos
#
#       lokasi  harga_rata2  terjual  rating  jumlah_review          toko  \
# 96  bandung       64480.0     9400     4.9           3600  qrproject.id
#
#     umur_bulan_toko  n_produk_toko  pengikut_toko
# 96                3              7          13200

# %%
df[df['toko'] == 'sexy.crowd']
# Out:
#                                                    nama       kategori  jenis  \
# 101   Star+Baru CD Munafie Celana Dalam Boxer Munafi...  Pakaian Dalam  boxer
# 1631  Star+Celana Dalam Pria Munafie BOXER MAN UNDER...  Pakaian Dalam  boxer
#
#               lokasi  harga_rata2  terjual  rating  jumlah_review        toko  \
# 101   jakarta utara        9025.0     6700     4.9           1100  sexy.crowd
# 1631  jakarta utara       11900.0      698     4.8            169  sexy.crowd
#
#       umur_bulan_toko  n_produk_toko  pengikut_toko
# 101                 5             71          21700
# 1631                5             71          21800

# %% [markdown]
# #### The most effective store is qrproject.id within 3 months they can have 13200 followers with 9600 sales in tshirt market, in the boxer market sexy.crowd is one of the best with 21700 follower. The newcomers can spectating their store page and also their social media. anfashion11 and erwinstore123 also can be another alternative to learn from spectating.

# %% [markdown]
# ### What is the most popular store and what products are they sell?

# %%
df.head()
# Out:
#                                                 nama kategori jenis  \
# 0  Star+[PROMO] KAOS POLOS LENGAN PENDEK COTTON C...   Atasan  kaos
# 1    Star+KAOS POLOS LENGAN PENDEK COTTON COMBED 30S   Atasan  kaos
# 2  StarKaos Polos Cotton Combed 30s Distro Grosir...   Atasan  kaos
# 3  Star[LANGSUNG DARI PABRIK] [HARGA RESELLER] Ka...   Atasan  kaos
# 4  Star+[LANGSUNG DARI PABRIK] Kaos Polos cotton ...   Atasan  kaos
#
#            lokasi  harga_rata2  terjual  rating  jumlah_review  \
# 0  jakarta utara       27800.0    10000     4.9          90600
# 1        bandung       23900.0    10000     4.8          71800
# 2        bandung       23900.0    10000     4.7          80000
# 3        bandung       27000.0    10000     4.9          43200
# 4  jakarta utara       30800.0    10000     4.9          69900
#
#                 toko  umur_bulan_toko  n_produk_toko  pengikut_toko
# 0  tokyo_urban_style               18              5          74600
# 1  yoonacollection24               36             21          58600
# 2          kaospedia               36             39         105700
# 3    galerykaospolos               48            185         117000
# 4        redtomatoes               24             14         111300

# %%
top = df[df['terjual'] == 10000]
top2 = top[top['pengikut_toko'] >= 1000000]
top2.groupby(['toko'])['nama'].count()
# Out:
# toko
# erigostore              20
# supplierhijabfashion     8
# fygalery                 2
# aceboutique              1
# Name: nama, dtype: int64

# %%
top2[top2['toko'] == 'erigostore'].groupby(['kategori','jenis'])['nama'].count().sort_values(ascending=False)
# Out:
# kategori        jenis
# Celana Panjang  chino                 9
# Outerwear       jaket                 5
# Atasan          kaos                  5
# Outerwear       sweater & kardigan    1
# Name: nama, dtype: int64

# %%
top2[top2['toko'] == 'supplierhijabfashion'].groupby(['kategori','jenis'])['nama'].count().sort_values(ascending=False)
# Out:
# kategori       jenis
# Pakaian Dalam  boxer         2
# Atasan         kaos          2
# Pakaian Dalam  kaos dalam    1
# Name: nama, dtype: int64

# %%
top2[top2['toko'] == 'fygalery'].groupby(['kategori', 'jenis'])['nama'].count().sort_values(ascending=False)
# Out:
# kategori       jenis
# Pakaian Dalam  boxer    1
# Name: nama, dtype: int64

# %%
top2[top2['toko'] == 'aceboutique'].groupby(['kategori'])['nama'].count().sort_values(ascending=False)
# Out:
# kategori
# Pakaian Dalam    1
# Name: nama, dtype: int64

# %% [markdown]
# #### The most popular store with sales over 10k and follower over 1M are erigostore with chino market as their top market and the other store in underclothes market are supplierhijabfashion, fygalery and aceboutique
